# %%
import numpy as np
marks = np.array([60,70,69,79,80,80,90])
marks
# Out:
# array([60, 70, 69, 79, 80, 80, 90])

# %%
print("avg",marks.mean())
print("highest",marks.max())
print("above 70=",marks[marks>70])
# Out:
# avg 75.42857142857143
# highest 90
# above 70= [79 80 80 90]
